# %% [markdown]
# # Ethical Moderation

# %% [markdown]
# Note: The documentation for this lab can be found [here](https://dylanirlbeck.github.io/ethical-moderation). Various sections will be linked throughout this lab.

# %% [markdown]
# ## Background and Learning Objectives
#
# Read the [background](https://dylanirlbeck.github.io/ethical-moderation/project#background) and [learning objectives](https://dylanirlbeck.github.io/ethical-moderation/project#learning-objectives).

# %% [markdown]
# ***

# %% [markdown]
# ## Lab
# _Sport-It_ is a popular social media platform known for its unique, sports-based community. Over the last few months,
# _Sport-It_ has been rapidly growing in scale: the number of daily active users increased by 200% in the last month alone!
# As a result, there has been an explosion in the number of posts made on the platform. It is untenable for the moderators
# at _Sport-It_ to continue conducting manual review of posts, and so they’ve hired you to design an automated content moderation system.
#
# These moderators are very intentional about their moderation: they only allow posts about sports. Topics like politics, finance,
# and cooking, for example, are not allowed on _Sport-It_. They’ve directed you to write software that removes all posts not directly
# related to sports.

# %% [markdown]
# ## Required Libraries
# Required libraries:
#     * beautifultable

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Part 1: "Naive" Moderation
#
# See https://dylanirlbeck.github.io/ethical-moderation/project#part-1-naive-moderation.

# %%
from lab import __version__, data_tools, display, utilities
from math import exp, log

print('Content filtering lab, version', __version__)
# Out:
# Content filtering lab, version 0.1

# %% [markdown]
# ### Using the Training Data
# We must use training data to “train” Naive Bayes. This training data consists of real posts from Sport-It pre-labeled as "on-topic" or "off-topic" by the moderators.
#
# Each datapoint in the training set contains __text (the post title)__, and a label __'y' or 'n' (whether the post is on-topic or off-topic, respectively)__. Here is an example:
# <blockquote>y: Musgrove throws first no-hitter in Padres history.</blockquote>
# Here, the moderators have labeled this post as on-topic, as it fully pertains to baseball.

# %%
# If you'd like more training data, you can increase the limit value.
#
training_data = data_tools.parse_data('./data/politics.csv', './data/espn.txt', limit=300)

# %% [markdown]
# Now that we parsed our data, let's take a look at some of the data points to get a sense of how the moderators think.
#
# As you look through the dataset, ask yourself (alternatively, if you're working in a group, have a discussion): __Do you agree with the labels provided? What would you change?__

# %%
display.display_labelled_data(training_data)
# Out:
# +--------+--------------------------------------------------------------------+
# | Valid? |                      Title of post submission                      |
# +--------+--------------------------------------------------------------------+
# |   y    |      Turner homers, Dodgers beat Nats 1-0 on champs' ring day      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | DeVos undoes Obama student loan protections; defaults expected to  |
# |        |                                rise                                |
# +--------+--------------------------------------------------------------------+
# |   n    |       Trumps Reversals Come After Crash Course on the Issues       |
# +--------+--------------------------------------------------------------------+
# |   n    |     EPA: US Steel leaks chemical into Lake Michigan tributary      |
# +--------+--------------------------------------------------------------------+
# |   y    |        Contreras, Báez, Bote HRs lift Cubs over Brewers 5-3        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |  The FBI suspected Carter Page was working as an agent for Russia  |
# +--------+--------------------------------------------------------------------+
# |   y    |        Lakers pull away after ejections, rout Nets 126-101         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Rays take 3-game losing streak into matchup with Red Sox      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |     Jazz beat Kings 128-112, extend home winning streak to 24      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |              Teheran, Tigers to face Plesac, Indians               |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Ruf's homer, Gausman's arm help Giants beat Padres 3-2 in 10    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Airlines Treat People Like Dirt Because the Republicans in Congres |
# |        |                             s Let Them                             |
# +--------+--------------------------------------------------------------------+
# |   y    |         Astros batter A's 9-2 to complete four-game sweep          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |  Trumps saber-rattling is North Koreas propaganda dream come true  |
# +--------+--------------------------------------------------------------------+
# |   n    |  Expert who called Trumps election win, now predicts impeachment   |
# +--------+--------------------------------------------------------------------+
# |   y    | Buehler to start home opener for Los Angeles against the Nationals |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | New Evidence Suggests Mercer-Backed Super PAC Unlawfully Coordinat |
# |        | ed with Trump Campaign; Bannon Front did not Comply with Californi |
# |        |                               a Law                                |
# +--------+--------------------------------------------------------------------+
# |   n    | Classified docs contradict Nunes surveillance claims, GOP and Dem  |
# |        |                            sources say                             |
# +--------+--------------------------------------------------------------------+
# |   y    |    Martinez's 2-run double in 12th lifts Red Sox over Rays 6-5     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Baltimore Orioles' Trey Mancini gets standing ovation in first hom |
# |        |                 e at-bat since return from cancer                  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Why NFL draft prospect Rashod Bateman is ready for the moment, on  |
# |        |                         and off the field                          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | The bombing of Afghanistan shows the US is led by a one-man wild c |
# |        |                                ard                                 |
# +--------+--------------------------------------------------------------------+
# |   n    | Spending blind: Shocking education report shows taxpayers pay mill |
# |        |                  ions for subpar charter schools                   |
# +--------+--------------------------------------------------------------------+
# |   n    | China says North Korea tension has to be stopped before it reaches |
# |        |                         irreversible stage.                        |
# +--------+--------------------------------------------------------------------+
# |   y    |      Taylor's homer propels Dodgers to 9-5 win over Nationals      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |  Fantasy hoops weekly rankings: Big week ahead for Bulls players?  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |       Arihara scheduled to start for Rangers against Padres        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Russian Spy Met Trump Adviser Carter Page and Thought He Was an Id |
# |        |                                iot                                 |
# +--------+--------------------------------------------------------------------+
# |   n    |   The Trump Doctrine: Eat cake, fire missiles, learn on the job    |
# +--------+--------------------------------------------------------------------+
# |   n    | Spicer apologized to a Jewish megadonor but not to Jewish members  |
# |        |                            of Congress                             |
# +--------+--------------------------------------------------------------------+
# |   n    | Donald Trump, who doesnt read books, is ignorant of history  and s |
# |        |                   o is his pet chump Sean Spicer                   |
# +--------+--------------------------------------------------------------------+
# |   n    |      Donald Trump just quietly signed away more womens rights      |
# +--------+--------------------------------------------------------------------+
# |   n    | The Trump Administration Lost Again in Court, This Time on Voter I |
# |        |                                 D                                  |
# +--------+--------------------------------------------------------------------+
# |   n    | Did he or didnt he? Trump contradicts himself on whether he knew S |
# |        |                            teve Bannon                             |
# +--------+--------------------------------------------------------------------+
# |   y    |     Martinez scheduled to start for Cardinals against Brewers      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |      Trump arrives at Mar-a-Lago for three-day Easter weekend      |
# +--------+--------------------------------------------------------------------+
# |   y    |      Sánchez homers again, Kluber debuts, Yanks beat Jays 5-3      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |            Fantasy baseball: Believing in Byron Buxton?            |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Seattle Seahawks re-sign Damarious Randall, moving him to CB    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |        Peralta pitches 5 innings as Brewers blank Cubs 4-0         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump sparks first protest in space: Space networks screw-you mess |
# |        |                     age flies 90,000 feet high                     |
# +--------+--------------------------------------------------------------------+
# |   y    |     Angels win 7-5 in home opener for Florida-based Blue Jays      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Webb scheduled to start as San Francisco hosts Colorado       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Susan Rice was in the right, and Devin Nunes was oh so wrong: Repo |
# |        |                                 rt                                 |
# +--------+--------------------------------------------------------------------+
# |   y    |             Keuchel, White Sox to face Dunn, Mariners              |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |              Nancy Pelosi: Sean Spicer must be fired               |
# +--------+--------------------------------------------------------------------+
# |   n    |           Howard Stern: Sean Spicer Speaks Fluent Moron            |
# +--------+--------------------------------------------------------------------+
# |   n    | The butchers bill keeps growing: Donald Trump abuses his own voter |
# |        |                      s  and yet they love him                      |
# +--------+--------------------------------------------------------------------+
# |   y    | Kyrie Irving, Dennis Schroder both tossed from Los Angeles Lakers- |
# |        |                         Brooklyn Nets game                         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | The Republican Won, but Voters Shifted Left in the Kansas Special  |
# |        |                              Election                              |
# +--------+--------------------------------------------------------------------+
# |   y    |    Indians beat Tigers 9-3, overcome Baddoo 1st-pitch home run     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |       Orioles to start Harvey in home opener against Boston        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Glenn Beck: Trump another Republican who said stuff and didnt mean |
# |        |                                 it                                 |
# +--------+--------------------------------------------------------------------+
# |   n    |  Trump Is Now Threatening to Sabotage Millions of Insurance Plans  |
# +--------+--------------------------------------------------------------------+
# |   y    |       Atlanta visits Charlotte after Young's 42-point outing       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump tells Fox how he ordered strikes on Syria over dessert with  |
# |        |                                 Xi                                 |
# +--------+--------------------------------------------------------------------+
# |   y    |     Sacramento travels to play Western Conference-leading Utah     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |           Skubal expected to start for Tigers at Indians           |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |   Fantasy baseball: How to handle the Fernando Tatis Jr. injury    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | OnPolitics Today: Trumps flipping on issues faster than we can kee |
# |        |                                p up                                |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump tells Fox how he ordered strikes on Syria over dessert with  |
# |        |                                 Xi                                 |
# +--------+--------------------------------------------------------------------+
# |   n    |            DeVos Undoes Obama Student Loan Protections             |
# +--------+--------------------------------------------------------------------+
# |   n    |         Feds can fund 7 miles of Trump border wall: report         |
# +--------+--------------------------------------------------------------------+
# |   y    | New York Mets place Dellin Betances on injured list, add Trevor Hi |
# |        |                       ldenberger to bullpen                        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |               Nature supports the march for science                |
# +--------+--------------------------------------------------------------------+
# |   y    | 2021 NFL draft QB projections: How good will Trevor Lawrence, Just |
# |        |                     in Fields, Zach Wilson be?                     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |           Clippers play the Rockets on 3-game win streak           |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | While the U.S. wasnt looking, Russia and Iran began carving out a  |
# |        |                     bigger role in Afghanistan                     |
# +--------+--------------------------------------------------------------------+
# |   n    |    Trump wont let reality stop him from lying about Susan Rice     |
# +--------+--------------------------------------------------------------------+
# |   y    |         Lillard and the Trail Blazers take on the Pistons          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | United Airlines Spent Millions Fighting Proposals To Protect Passe |
# |        |                            nger Rights                             |
# +--------+--------------------------------------------------------------------+
# |   y    |    Gibson strong rebound for Rangers in 2-1 win over Blue Jays     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | New Orleans Pelicans give Zion Williamson keys to offense, drive a |
# |        |                            way with win                            |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |                 Blue Jays look to end 3-game slide                 |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Fox Business Host Corrects Trump When He Says He Fired Missiles At |
# |        |                                Iraq                                |
# +--------+--------------------------------------------------------------------+
# |   n    |    Trump faces Chinese mockery following embarrassing reversals    |
# +--------+--------------------------------------------------------------------+
# |   n    | The stunning hypocrisy of Scott Pruitts request for around-the-clo |
# |        |                           ck bodyguards                            |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump is taking credit for jobs companies planned years in advance |
# +--------+--------------------------------------------------------------------+
# |   n    | Get Set For Trump Revisions To Your Affordable Care Act Insurance  |
# +--------+--------------------------------------------------------------------+
# |   n    |            Manafort firm received Ukraine ledger payout            |
# +--------+--------------------------------------------------------------------+
# |   y    | Los Angeles Dodgers' Justin Turner still feels 'big void' from not |
# |        |          being on field for final out of World Series win          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |              Prediction prof: Trump will be impeached              |
# +--------+--------------------------------------------------------------------+
# |   y    |     Judges order women suing Deshaun Watson to disclose names      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Golden State Warriors president/COO Rick Welts to retire after sea |
# |        |                                son                                 |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Republican climate change deniers condemned as woefully ignorant b |
# |        |                            y scientists                            |
# +--------+--------------------------------------------------------------------+
# |   y    | Chicago Bulls star Zach LaVine scores 39 points in first half of l |
# |        |                        oss to Atlanta Hawks                        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |                Sorry America, Your Taxes Arent High                |
# +--------+--------------------------------------------------------------------+
# |   y    |    Stroman sharp in return, Mets beat Phillies 8-4 for 1st win     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Secret Service costs for Trump family protection continue to mount |
# +--------+--------------------------------------------------------------------+
# |   y    |      Five teams that could take down the Dodgers this season       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |                  Spicer: I let the president down                  |
# +--------+--------------------------------------------------------------------+
# |   n    | GOP governor absurdly claims voting hours should be cut so media c |
# |        |                  an report results before bedtime                  |
# +--------+--------------------------------------------------------------------+
# |   y    |      Tatum's career-high 53 help Celtics top T-Wolves 145-136      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |     Hometown no-no: Musgrove no-hitter for Padres vs. Rangers      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Philadelphia Eagles bolster defense with LB Eric Wilson, re-sign R |
# |        |                          B Jordan Howard                           |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |     DeGrom Ks 14, but Chisholm's HR, Rogers' gem lift Marlins      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |  Los Angeles Lakers to unveil 2020 NBA championship banner May 12  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |   Chicago Cubs' Craig Kimbrel gets five outs to notch 350th save   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trumps claim that Susan Rice broke the law has not been confirmed  |
# |        |             by intelligence reports, say GOP and Dems              |
# +--------+--------------------------------------------------------------------+
# |   n    |     Why an independent counsel is necessary in election probe      |
# +--------+--------------------------------------------------------------------+
# |   n    | Panicked Borrowers, and the Education Departments Unsettling Silen |
# |        |                                 ce                                 |
# +--------+--------------------------------------------------------------------+
# |   n    |         64% of Republicans want to see Trumps tax returns          |
# +--------+--------------------------------------------------------------------+
# |   y    |    Duffy dazzles, Merrifield's 3 RBIs lift Royals past Indians     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump on North Korea: after listening for 10 minutes, I realized i |
# |        |                           ts not so easy                           |
# +--------+--------------------------------------------------------------------+
# |   y    |          Montas expected to start for Athletics at Astros          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |           Updated PPR fantasy football rankings 2021: K            |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |               The MOAB bomb costs $16 million each.                |
# +--------+--------------------------------------------------------------------+
# |   n    |     ICE targets mother with no criminal record for deportation     |
# +--------+--------------------------------------------------------------------+
# |   n    |     Audience Laughs as Kellyanne Conway Complains About Liars      |
# +--------+--------------------------------------------------------------------+
# |   n    | Spicer refuses to say if Trump was in Situation Room for Afghanist |
# |        |                  an strike, flees amid questions.                  |
# +--------+--------------------------------------------------------------------+
# |   y    | Nike suspends Deshaun Watson sponsorship; Beats by Dre ends deal,  |
# |        |                            sources say                             |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Devin Booker scores 27 points, Suns rout Wizards 134-106      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Boston Red Sox OF J.D. Martinez goes on COVID-19 injured list; Mic |
# |        |                        hael Chavis recalled                        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |  Wainwright to start home opener for St. Louis against Milwaukee   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Reyes homers twice, Plesac strong as Indians beat Tigers      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Williamson scores 37 points, Pelicans beat 76ers 101-94       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Bogaerts has 4 of Boston's 16 hits in 11-2 win over Rays      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Tony Finau gets surprise call from Tampa Bay Buccaneers' Tom Brady |
# |        |                      during Masters rain delay                     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |         Trump privately signs anti-Planned Parenthood law          |
# +--------+--------------------------------------------------------------------+
# |   y    | Los Angeles Dodgers place Cody Bellinger on 10-day IL with calf in |
# |        |                                jury                                |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Answering the biggest fantasy football questions of the 2021 offse |
# |        |              ason: 32 NFL reporters give early advice              |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |            Manafort Firm Received Ukraine Ledger Payout            |
# +--------+--------------------------------------------------------------------+
# |   n    |  British intel agency reported Trump campaign Russia ties: Report  |
# +--------+--------------------------------------------------------------------+
# |   y    |          Lyles expected to start as Texas hosts San Diego          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Means scheduled to start for Baltimore against New York       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |  No, Trump Has Not Created 600,000 Jobs Since Becoming President   |
# +--------+--------------------------------------------------------------------+
# |   n    |            Manafort firm received Ukraine ledger payout            |
# +--------+--------------------------------------------------------------------+
# |   y    |  Fantasy NBA Daily Notes: Mining the Hornets for fantasy starters  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |        Pineda expected to start as Minnesota hosts Seattle         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Detroit Tigers starter Julio Teheran scratched before start with t |
# |        |                            riceps issue                            |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |     White Sox to start Lynn against Kansas City in home opener     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Howard Dean was warning people about the opioid crisis a decade ag |
# |        |                                 o                                  |
# +--------+--------------------------------------------------------------------+
# |   y    | Brain of Phillip Adams, former NFL player who killed five, to be e |
# |        |                          xamined for CTE                           |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |             Chicago plays Atlanta on 3-game win streak             |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Im Rep. Beth Fukumoto, former Republican, current Independent, pro |
# |        |                         spective Democrat                          |
# +--------+--------------------------------------------------------------------+
# |   y    | Los Angeles Dodgers' Dave Roberts concerned that Trevor Bauer gett |
# |        |                       ing singled out by MLB                       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Utah brothers launch billboard campaign to send message to Chaffet |
# |        |                                 z                                  |
# +--------+--------------------------------------------------------------------+
# |   y    |    Trent scores career-high 44, Raptors rout Cavaliers 135-115     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Ex-MI6 chief accuses Donald Trump of secretly borrowing from Russi |
# |        |  a to keep his property empire afloat during the financial crisis  |
# +--------+--------------------------------------------------------------------+
# |   y    | Vaccine side effects land New York Yankees' Gio Urshela on COVID l |
# |        |                                ist                                 |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |  Blue Jays to start Stripling against Los Angeles in home opener   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |   Gausman expected to start for San Francisco against San Diego    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    García HR, 5 RBIs; Brewers end Cards' 4-game win streak, 9-5    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Congressmen Gaetz and Soto Propose Legislation to Reschedule Marij |
# |        |                                uana                                |
# +--------+--------------------------------------------------------------------+
# |   n    | Scott Pruitt requests funds for a 24/7 fleet of bodyguards, as the |
# |        |           EPA is poised to cut health and safety programs          |
# +--------+--------------------------------------------------------------------+
# |   y    | Patrick McCaw, reserve on 2019 title team, waived by Toronto Rapto |
# |        |                                 rs                                 |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Mets rally in 9th, win home opener vs Marlins on bizarre HBP    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | President Trump gets almost everything wrong about the Kansas spec |
# |        |                ial election in a dumbfounding tweet                |
# +--------+--------------------------------------------------------------------+
# |   n    | Airlines Treat People Like Dirt Because the Republicans in Congres |
# |        |                             s Let Them                             |
# +--------+--------------------------------------------------------------------+
# |   y    |     Eastern Conference battle pits Milwaukee against Charlotte     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |  Trump backtracks on China, wont label it a currency manipulator   |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump Says He May Freeze Subsidies to the Poor Until Democrats Rep |
# |        |                           eal Obamacare                            |
# +--------+--------------------------------------------------------------------+
# |   y    | Nigeria's Josh Okogie praises Mike Brown, makes history at All-Sta |
# |        |                             r weekend                              |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |                From Puerto Rico to the World Series                |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump may halt insurer payments to force Democrats to table on hea |
# |        |                              lthcare                               |
# +--------+--------------------------------------------------------------------+
# |   y    |      Posey, Longoria go deep again as Giants top Mariners 6-3      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Orioles' sweep sends Red Sox to 2nd 0-3 start ever in Fenway    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Behind closed doors, Trump signs bill allowing states to strip fed |
# |        |        eral family planning dollars from abortion providers        |
# +--------+--------------------------------------------------------------------+
# |   n    | President Trump changes stance on 4 campaign positions in just 1 d |
# |        |                                 ay                                 |
# +--------+--------------------------------------------------------------------+
# |   y    | Could these six teams still win the NFL offseason? Why the Packers |
# |        | , Saints, Eagles, Rams, Colts and Falcons have been quiet; what's  |
# |        |                                next                                |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump Budget Director Admits Their Goal Is High Inequality, Not Lo |
# |        |                             w Deficits                             |
# +--------+--------------------------------------------------------------------+
# |   y    |    Stanton-ian grand slam in bleachers leads Yanks over O's 7-0    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Segura bails out Phils' bullpen with HR in 10th to beat Mets    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |                Fantasy Baseball 2021 roto rankings                 |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Fantasy baseball daily notes -- Pitcher and hitter rankings for Th |
# |        |                               ursday                               |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Gray takes no-hitter into 7th, Rockies beat D-Backs, 7-3      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |            Trump says he created 600,000 jobs. Not true            |
# +--------+--------------------------------------------------------------------+
# |   n    |  George W. Bush Calls Foreign Aid A Moral And Security Imperative  |
# +--------+--------------------------------------------------------------------+
# |   y    |                 Nationals look to end 3-game skid                  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Trimmer Guerrero helps Jays finish series win over Yanks      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Arkansas Razorbacks guard Moses Moody declares for NBA draft    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |       Updated non-PPR fantasy football rankings 2021: Kicker       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |       Dan Rather Thinks We Need Patriotism, Not Nationalism        |
# +--------+--------------------------------------------------------------------+
# |   n    | Trumps EPA chief Scott Pruitt calls for an exit to the Paris clima |
# |        |                            te agreement                            |
# +--------+--------------------------------------------------------------------+
# |   n    |        Dems to unveil populist agenda showing Sanders sway         |
# +--------+--------------------------------------------------------------------+
# |   y    | NFL draft 2021: Mel Kiper, Todd McShay draft dueling superteams of |
# |        |                         the best prospects                         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | The most ill-informed, under-prepared, and psychologically ill-equ |
# |        |                   ipped president in US history                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Its not too late to get rid of FBI Director James Comey, Trump say |
# |        |                                 s                                  |
# +--------+--------------------------------------------------------------------+
# |   n    | Silicon Valley is beginning to fight the Trump administrations net |
# |        |                           neutrality plan                          |
# +--------+--------------------------------------------------------------------+
# |   n    | Ivanka Trump: Majority of young US women view Donald Trumps daught |
# |        |                     er negatively, poll finds                      |
# +--------+--------------------------------------------------------------------+
# |   y    | Toronto Raptors guards Fred VanVleet, DeAndre' Bembry, Los Angeles |
# |        |          Lakers' Talen Horton-Tucker suspended 1 game each         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | It looks like Donald Trump is trying to bomb his way to popularity |
# |        |                                 .                                  |
# +--------+--------------------------------------------------------------------+
# |   y    |       Blue Jays' George Springer now dealing with quad issue       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump signs law that allows states to deny funding to Planned Pare |
# |        |                               nthood                               |
# +--------+--------------------------------------------------------------------+
# |   y    | Jim Schwartz returning to Tennessee Titans as defensive assistant  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |     Analysts identify #SyriaHoax as Russian-fueled propaganda      |
# +--------+--------------------------------------------------------------------+
# |   n    |             Sanders: Dems win if we mobilize & educate             |
# +--------+--------------------------------------------------------------------+
# |   n    | President Trumps vacations already set to surpass Obamas total tra |
# |        |                            vel expenses                            |
# +--------+--------------------------------------------------------------------+
# |   y    |  Oakland takes 6-game losing streak into matchup with Los Angeles  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |  Berrios to start home opener for Minnesota against the Mariners   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |             Ex-Pentagon chief: Its not Trumps military             |
# +--------+--------------------------------------------------------------------+
# |   n    | Why are California legislators getting decent approval ratings? Th |
# |        |                      eyre getting things done                      |
# +--------+--------------------------------------------------------------------+
# |   n    |  Mexican ambassador: Our approach to Trump is strategic patience   |
# +--------+--------------------------------------------------------------------+
# |   n    | FBI says Jeff Sessions pick for Trump team was an alleged Russian  |
# |        |                               agent                                |
# +--------+--------------------------------------------------------------------+
# |   n    |   Climate Change Is A National Security Issue, Says The Military   |
# +--------+--------------------------------------------------------------------+
# |   y    |                   Fantasy Baseball Closer Chart                    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |               This could be the end for Bill OReilly               |
# +--------+--------------------------------------------------------------------+
# |   n    |    Trumps Tweets About North Korea Are Making Bad Matters Worse    |
# +--------+--------------------------------------------------------------------+
# |   n    | FBI obtained FISA warrant to monitor former Trump adviser Carter P |
# |        |                                age                                 |
# +--------+--------------------------------------------------------------------+
# |   y    | Best team fits for wide receivers in the 2021 NFL draft: Landing s |
# |        |  pots for Ja'Marr Chase, DeVonta Smith, Jaylen Waddle, Kyle Pitts  |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |        Minnesota hosts Chicago after LaVine's 50-point game        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |          Ryu scheduled to start for Blue Jays at Rangers           |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Our hottest hot takes one week into the 2021 MLB season       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Matthew Berry's free-agency loves and hates, and what to do with W |
# |        |                               eek 18                               |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |              Trump Lifting His Federal Hiring Freeze               |
# ...
# |   y    |        Fantasy baseball: The good, the Baddoo and the ugly         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Mercedes gets 3 more hits, White Sox blank Mariners 6-0       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |         Trumps tax returns will be immediately under audit         |
# +--------+--------------------------------------------------------------------+
# |   y    |          Minor scheduled to start for Royals at White Sox          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | The wife of the Alabama governor who just resigned orchestrated hi |
# |        |              s downfall after she caught him cheating              |
# +--------+--------------------------------------------------------------------+
# |   y    |     Duffy wins, Merrifield drives in 3 as Royals blank Indians     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Donald Trump, who doesnt read books, is ignorant of history  and s |
# |        |                   o is his pet chump Sean Spicer                   |
# +--------+--------------------------------------------------------------------+
# |   y    | Pickleball? UFC's Julian Marquez challenges Patrick Mahomes, other |
# |        |                    Chiefs stars, and they accept                   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Washington hires NFL's first Latina coordinator of football progra |
# |        |                                 ms                                 |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | President Trump gets almost everything wrong about the Kansas spec |
# |        |                ial election in a dumbfounding tweet                |
# +--------+--------------------------------------------------------------------+
# |   n    | Carter Page Refuses To Disclose Who Brought Him Onto Trump Campaig |
# |        |                                 n                                  |
# +--------+--------------------------------------------------------------------+
# |   n    |      Jared and Ivanka Are Not Good People. They Are Enablers.      |
# +--------+--------------------------------------------------------------------+
# |   n    |    No Environmental Impact Study? No Border Wall, Lawsuit Says     |
# +--------+--------------------------------------------------------------------+
# |   n    | Trump made sure the media didnt see him sign a bill to cut Planned |
# |        |                        Parenthood funding .                        |
# +--------+--------------------------------------------------------------------+
# |   y    |      Andrus gets 4 hits, Rangers beat Jays 7-3 to avoid sweep      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Muslim woman stabbed and beaten after attacker tries to tear off h |
# |        |                              er hijab                              |
# +--------+--------------------------------------------------------------------+
# |   y    |    Senzatela sizzling on cool night, Rox beat Diamondbacks 8-0     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Arenado's late HR lifts Cards over Brewers in home debut      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Trumps pledge to allow political action from churches may come in  |
# |        |                              tax bill                              |
# +--------+--------------------------------------------------------------------+
# |   y    |      Cain 2 HRs, Woodruff sharp, Brewers beat Cubs 4-2 in 10       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |     Hendricks expected to start for Chicago against Milwaukee      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |            Sanders: Trump will be a one-term president             |
# +--------+--------------------------------------------------------------------+
# |   y    |               Thunder face the 76ers on 5-game slide               |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Bogaerts has 4 of Boston's 16 hits in 11-2 win over Rays      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Astros remain hot in home opener with 6-2 win over Athletics    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |          Twins rally for 3-2 victory over Baddoo, Tigers           |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | DeVos undoes Obama student loan protections; defaults expected to  |
# |        |                                rise                                |
# +--------+--------------------------------------------------------------------+
# |   n    | Rex Tillerson ditches U.S. press pool for surprise visit with Puti |
# |        |                                 n                                  |
# +--------+--------------------------------------------------------------------+
# |   y    | NBA mailbag: Should the league prevent top buyout players from sig |
# |        |                     ning with the best teams?                      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |       Beal's late heroics lift Wizards past Warriors 110-107       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Vladimir Putin says US-Russia relations are worse since Donald Tru |
# |        |                           mp took office                           |
# +--------+--------------------------------------------------------------------+
# |   n    |      Nunes wont hold town hall? Opponents schedule one anyway      |
# +--------+--------------------------------------------------------------------+
# |   y    | Fire in the belly: How D-III's Quinn Meinerz turned doubts into fu |
# |        |                          el for NFL draft                          |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |         Rays to start Hill in home opener against New York         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |   Judge Gorsuch favors corporate goliaths over small businesses    |
# +--------+--------------------------------------------------------------------+
# |   y    |      Sexton scores 27 points, Cavaliers beat Thunder 129-102       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |       Stephen Curry scores 38 points, Warriors beat Rockets        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Schumer: If Trump doesnt release his tax returns, its going to mak |
# |        |                      e tax reform much harder                      |
# +--------+--------------------------------------------------------------------+
# |   n    | Cross dressers in the building: A Capitol staffer warns when LGBT  |
# |        |                           students visit                           |
# +--------+--------------------------------------------------------------------+
# |   y    |      Meadows, Arozarena homer, AL champ Rays beat Yankees 4-0      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Silicon Valley is beginning to fight the Trump administrations net |
# |        |                           neutrality plan                          |
# +--------+--------------------------------------------------------------------+
# |   y    |    Bridges leads Hornets to 127-119 win over short-handed Bucks    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Richard Posner: The Real Corruption Is the Ownership of Congress b |
# |        |                             y the Rich                             |
# +--------+--------------------------------------------------------------------+
# |   n    | Attorney General Jeff Sessions Is Using His Job to Purge America o |
# |        |                  f People Who Dont Look Like Him                   |
# +--------+--------------------------------------------------------------------+
# |   n    |       Roger Stone gets his facts from the National Enquirer        |
# +--------+--------------------------------------------------------------------+
# |   y    |    Smith solid in 1st start as Diamondbacks cool off Reds, 8-3     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | A complete waste: What Trump said about war in Afghanistan before  |
# |        |              he dropped the $16m Mother of all Bombs               |
# +--------+--------------------------------------------------------------------+
# |   y    | Texas A&M Aggies QB Kellen Mond has 'upside' as intriguing Day 2 N |
# |        |                    FL draft option, scouts say                     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |       Red Sox extend win streak to 5, beat Orioles 6-4 in 10       |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Tampa Bay Rays' Chris Archer heads to IL after exiting start with  |
# |        |                  right lateral forearm tightness                   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Toronto Blue Jays, GM Ross Atkins reach five-year extension     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |   Top U.S. Election Official: There Is No Voting Fraud Epidemic    |
# +--------+--------------------------------------------------------------------+
# |   n    |       Donald Trump just keeps saying things that arent true        |
# +--------+--------------------------------------------------------------------+
# |   y    |        Crawford's 3-run homer sends Giants past Rockies 4-3        |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |     Laureano's 2-run shot gives Athletics 7-3 win over Astros      |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |        Fantasy baseball forecaster for Week 2: April 12-18         |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | North Korea says it will ruthlessly ravage the United States if it |
# |        |                         comes under attack                         |
# +--------+--------------------------------------------------------------------+
# |   y    | Fantasy baseball daily notes -- Pitcher and hitter rankings for Fr |
# |        |                                iday                                |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    |    Middle East travellers to the US down 20%, says Marriott CEO    |
# +--------+--------------------------------------------------------------------+
# |   y    |  Sources: North Dakota State's Trey Lance to hold second pro day   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Is Stephen Bannon getting pushed out? The latest signs point to Ye |
# |        |                                 s.                                 |
# +--------+--------------------------------------------------------------------+
# |   y    | New York Mets get walk-off win vs. Miami Marlins on Michael Confor |
# |        |                  to's controversial hit by pitch                   |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Coach, broadcaster, esports icon: Inside the legacy of John Madden |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    |    Martinez (2B, 2 RBI), Vázquez HR leads Red Sox past Rays 9-2    |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   y    | Detroit Tigers pitching coach Chris Fetter rejoins team after COVI |
# |        |                           D-19 positive                            |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+
# |   n    | Attendees chant you lie at U.S. Rep. Joe Wilson during Granitevill |
# |        |                            e town hall                             |
# +--------+--------------------------------------------------------------------+
# |   y    |     Hawks win 120-108, overcome 50-point game by Bulls' LaVine     |
# |        |                                                                    |
# +--------+--------------------------------------------------------------------+

# %% [markdown]
# ### Evaluate the training data
#
# There are some posts, however, which still need labelling for the training set; the moderators have tasked you with assigning such labels. Each of these posts is not clearly on-topic or off-topic, so the moderators want you to decide.
#
#
# Before you go to implement the Naive Bayes algorithm, the moderators email you some additional data that they want to include in the training set. These posts apparently sparked significant internal discussion, since, in the eyes of the moderators, they aren't clearly on-topic or off-topic.
#
# As the lead engineer, you have considerable say over the design of the algorithm and curation of the training set. Before you "extend" the training data with these new sample posts, look through the labels assigned to the posts. Do you fully agree with the labels?
#
# If you change any labels in the training set, it is likely that the moderators will never know; the outcome on the moderation algorithm, though, could be profound.

# %%
additional_training_data = [
    ('y', 'Deshaun Watson Admits Encounters with Masseuses, Always Consensual'),
    ('y', 'Bruce Jenner is actually getting the Arthur Ashe Courage Award?'),
    ('y', 'The real Tim Tebow: anti gay, anti choice, and a very unexceptional QB who owes a great deal to a teammate who is very good at kicking long fieldgoals when Tim cant get near the red zone.'),
    ('y', 'TIL All NFL players have to do their physicals completely nude and are often nude for over an hour and a half. Many players have fears they were videotaped.'),
    ('y', 'Broncos Brandon Marshall kneels during national anthem, follows Colin Kaepernick’s path'),
    ('y', 'Megan Rapinoe says ‘not many, if any’ US womens soccer player’s would attend White House'),
    ('y', 'With the upcoming Thursday night NFL game, remember that this presents a simplified view of an entire culture, caricatures facial features based on race, depicts an outdated/inaccurate style of headdress, paints them as warmongering aggressors and overly glamorizes the violent side of their history.')
]

utilities.validate_labels(additional_training_data)
training_data.extend(additional_training_data)
display.display_labelled_data(additional_training_data)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-40-baa2bfdc1546> in <module>
#      11 ]
#      12
# ---> 13 utilities.validate_labels(additional_training_data)
#      14 training_data.extend(additional_training_data)
#      15 display.display_labelled_data(additional_training_data)
#
# ~/Code/other/ethical-moderation-lab/lab/utilities.py in validate_labels(data)
#      69     for elem in data:
#      70         if elem[0] != 'y' or elem[0] != 'n':
# ---> 71             raise Exception("The data labels must be either 'y' or 'n'!")
#
# Exception: The data labels must be either 'y' or 'n'!

# %% [markdown]
# ### Calculate probabilities
#
# As described in the lab writeup, the probabilities you need to calculate and subsequently compare for each post are ${P}(Type=On|Post)$ and ${P}(Type=Off|Post)$. We've provided some helper functions to calculate the various components of each probability's equation.
#
# For each post in the test set, you'll need to calculate these probabilities, compare them, and assign a label based on which probability is higher.

# %%
# Some useful statistics about the data.
#
training_data_statistics = data_tools.DataStats(training_data)

print(utilities.prior_probability('y', training_data_statistics))
# Out:
# 0.5008347245409015

# %% [markdown]
# We currently have the prior probabilities of both the on-topic and off-topic posts. In order to properly label posts on Sport-It as on-topic or off-topic, we also need to calculate the ${P}(Word|Type=On)$.
#
# In words, this is __the probability of each word appearing in an on-topic of off-topics post__. For this, we provide the `probability_word_given_label` function, demonstrated below.

# %%
print(utilities.probability_word_given_label("football", 'y', training_data_statistics))
print(utilities.probability_word_given_label("trump", 'n', training_data_statistics))
# Out:
# 0.004848093083387201
# 0.03533254156769596

# %% [markdown]
# ## Predicting Labels for Posts
# Time to see if our algorithm and model work! We now have the prior probabilities, as well as all the feature probabilities. We can correctly predict what label a post should have. For example if we were given the following post:
# <blockquote>The game last night was absolutely terrible!</blockquote>
#
# We should be able to __determine this post's label by the likelihood of it being on-topic and off-topic__:
#
# Once you have the probability of the post being on-topic or off-topic given the words in the posts, __choose the label corresponding to the highest probability of the two to correctly classify that post__.

# %% [markdown]
# Write a function `probability_label_given_post` that returns the probability of a label given a post. Then, using this function, write another function `classify_posts` that takes in the test data and assigns a label to each post.

# %%
def probability_label_given_post(post):
    # TODO write your code here
    pass
    
def classify_posts(posts):
    # TODO write your code here
    pass

# %% [markdown]
# The code below returns an array of tuples(labels, titles) based on the probabilities we found before. __With your group, quickly discuss the code and what it does__.

# %%
from lab.data_tools import parse_unlabeled_reddit_feed, parse_unlabeled_espn
espn_data = parse_unlabeled_espn('./data/test/espn.txt', limit=100)
politics_data = parse_unlabeled_reddit_feed('./data/test/politics.txt', limit=100)

testing_data = espn_data + politics_data
solution = [('y', e) for e in espn_data] + [('n', p) for p in politics_data]

def filter_posts(posts):
    """
    Input: array of posts to filter WITHOUT labels (see output of parse_unlabeled_espn/reddit_feed)
    Output: array of posts as tuples (label, post title), see output of parse_data
    """
    # your code here!
    result = []
    for submission in testing_data:
        validity = post_validity(submission)
        result.append((validity, submission))

    return result
filtering_result = filter_posts(testing_data)
display.display_labelled_data(filtering_result)

# %% [markdown]
# Great! Now we predicted labels for the posts in the testing set, based on the probabilities we calculated. Let’s go ahead and test how accurate your algorithm is! Run the code below to get a percentage of labels you correctly predicted.

# %%
def verify_algorithm(test_result, solution):
    """
    Input: result of the test labelling, and the solution labelling. They should both be arrays of tuples (see output of parse_data for info)
    Output: Entries in test_result that did not appear in solution -- also known as wrong entries
    """
    return list(set(test_result) - set(solution))

# %%
mislabelled = verify_algorithm(filtering_result, solution)
score = (1 - (len(mislabelled) / len(solution)))
print('Your accuracy is:', 100*score,'%')
display.display_labelled_data(mislabelled)

# %% [markdown]
# Look at the percentage you got when you ran the code block above. Were you expecting this score? Modify your past code, and see how the percentage changes. Try to get the best possible percentage. __Remember, incorrect moderation has real consequences for Sport-It.__

# %% [markdown]
# ***

# %% [markdown]
# # Part 2: The Consequences of Naivety

# %% [markdown]
# ### __More about the effects of a Naive content moderation algorithm can be found on the [ethical moderation website](https://dylanirlbeck.github.io/ethical-moderation/project#part-2-the-consequences-of-naivety)__

# %% [markdown]
# ***

# %% [markdown]
# # Part 3: Introducing Human Content Moderation

# %% [markdown]
# ### __More about human content moderation can be found on the [ethical moderation website](https://dylanirlbeck.github.io/ethical-moderation/project#part-3-introducing-human-content-moderation)__

# %% [markdown]
# ***

# %% [markdown]
# # Resources

# %% [markdown]
#  - [At the End of the Day Facebook Does What it Wants](https://s3.amazonaws.com/kvaccaro.com/documents/vaccaro_cscw2020.pdf)
#  - [Introduction to Bag-Of-Words Models](https://machinelearningmastery.com/gentle-introduction-bag-words-model/)
#  - [Introduction to NBC](https://towardsdatascience.com/introduction-to-naive-bayes-classification-4cffabb1ae54)
#  - [Laplace Smoothing](https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece#:~:text=Laplace%20smoothing%20is%20a%20smoothing%20technique%20that%20helps%20tackle%20the,the%20positive%20and%20negative%20reviews.)
#  - [Sample Data Examples](https://www.reddit.com/r/sports/controversial)
